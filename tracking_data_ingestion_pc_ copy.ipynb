# %%
import mlflow
import os

mlflow.set_tracking_uri("http://34.133.160.231:5000/")
mlflow.set_experiment("parcast-data-ingestion")

os.makedirs("artifacts", exist_ok=True)
with mlflow.start_run():
    mlflow.log_param("test_param", "hello")
    mlflow.log_metric("test_metric", 1.0)

print("Successfully connected to GCP MLFLOW!")
# Out:
# 🏃 View run bright-koi-68 at: http://34.133.160.231:5000/#/experiments/5/runs/59727967b2804141b0e502e58ef3c542
# 🧪 View experiment at: http://34.133.160.231:5000/#/experiments/5
# Successfully connected to GCP MLFLOW!
