# %%
from eda_pipeline import EdaConfig, run_eda

# Configure your EDA run.
# Tip: Start with a small limit while iterating, then increase once stable.
cfg = EdaConfig(
    dataset_name="sfpark_sensors",
    limit=5000,
    max_pages=2,
    # extra_params={"$where": "avail > 0"},  # example
    output_dir="outputs/eda",
    cache_dir="outputs/cache",
    use_cache=True,
)

meta = run_eda(cfg)
meta
# Out:
# {'before_columns': ['objectid',
#   'post_id',
#   'ms_pay_station_id',
#   'ms_space_num',
#   'on_offstreet_type',
#   'jurisdiction',
#   'pm_district_id',
#   'blockface_id',
#   'active_meter_flag',
#   'reason_code',
#   'meter_type',
#   'meter_vendor',
#   'meter_model',
#   'cap_color',
#   'street_id',
#   'street_name',
#   'street_num',
#   'street_seg_ctrln_id',
#   'longitude',
#   'latitude',
#   'pmr_route',
#   'shape',
#   'data_as_of',
#   'data_loaded_at',
#   'analysis_neighborhood',
#   'supervisor_district',
#   ':@computed_region_ajp5_b2md',
#   ':@computed_region_jwn9_ihcz',
#   ':@computed_region_6qbp_sg9q',
#   ':@computed_region_qgnn_b9vv',
#   ':@computed_region_26cr_cadq',
#   'collection_route',
#   'collection_subroute',
#   'collection_route_desc',
#   'collection_subroute_desc'],
#  'numeric_columns': ['objectid',
#   'ms_space_num',
#   'pm_district_id',
#   'blockface_id',
#   'street_id',
#   'street_num',
#   'street_seg_ctrln_id',
# ...
