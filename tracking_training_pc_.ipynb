# %%
import mlflow
import os

mlflow.set_tracking_uri("http://34.133.160.231:5000/")
mlflow.set_experiment("parkcast-training")

os.makedirs("artifacts", exist_ok=True)
with mlflow.start_run():
    mlflow.log_param("test_param", "hello")
    mlflow.log_metric("test_metric", 1.0)

print("Successfully connected to GCP MLFLOW!")
# Out:
# 🏃 View run learned-gull-891 at: http://34.133.160.231:5000/#/experiments/6/runs/93e4e9fe252c4cd68a95e123d3cf11c0
# 🧪 View experiment at: http://34.133.160.231:5000/#/experiments/6
# Successfully connected to GCP MLFLOW!
